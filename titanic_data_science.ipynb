# %% [markdown]
# <a href="https://colab.research.google.com/github/khaninasungkarr-cyber/data-science/blob/main/titanic_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')
print("5 data teratas")
print(df.head())
# Out:
# 5 data teratas
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = df[['survived','age','pclass','sex','sibsp','parch']]
df['age'] = df['age'].fillna(df['age'].mean())
df['sex'] = df['sex'].map({'male' : 0, 'female' : 1})
print("/n data telah dibersihkan:")
print(df.head())
# Out:
# /n data telah dibersihkan:
#    survived   age  pclass  sex  sibsp  parch
# 0         0  22.0       3    0      1      0
# 1         1  38.0       1    1      1      0
# 2         1  26.0       3    1      0      0
# 3         1  35.0       1    1      1      0
# 4         0  35.0       3    0      0      0

# %%
from sklearn.model_selection import train_test_split
x = df.drop('survived', axis = 1)
y = df['survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(x_train, y_train)
prediksi = model.predict(x_test)
akurasi = accuracy_score(y_test, prediksi)
print(f"/n akurasi model: {akurasi * 100 : 2f}%")
# Out:
# /n akurasi model:  82.122905%
